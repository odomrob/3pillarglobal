# %% [markdown]
# <a href="https://colab.research.google.com/github/odomrob/3pillarglobal/blob/master/pandasPractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df_one = pd.DataFrame({'k1':['A','A','B','B','C','C'],
                      'col1':[100,200,300,300,400,500],
                      'col2':['NY','CA','WA','WA','AK','NV']})
df_one
# Out:
#   k1  col1 col2
# 0  A   100   NY
# 1  A   200   CA
# 2  B   300   WA
# 3  B   300   WA
# 4  C   400   AK
# 5  C   500   NV

# %%
df_one['col2'].unique()
# Out:
# array(['NY', 'CA', 'WA', 'AK', 'NV'], dtype=object)

# %%
df_one['col2'].nunique()
df_one['k1'].nunique()
# Out:
# 3

# %%
df_one['col2'].nunique()
df_one['k1'].nunique()
# Out:
# 3

# %%
df_one['k1'].value_counts()
# Out:
# k1
# A    2
# B    2
# C    2
# Name: count, dtype: int64

# %%
df_one['k1'].drop_duplicates()
# Out:
# 0    A
# 2    B
# 4    C
# Name: k1, dtype: object

# %%
df_one['NEW'] = df_one['col1'] * 10

# %%
df_one
# Out:
#   k1  col1 col2   NEW
# 0  A   100   NY  1000
# 1  A   200   CA  2000
# 2  B   300   WA  3000
# 3  B   300   WA  3000
# 4  C   400   AK  4000
# 5  C   500   NV  5000

# %%
#NOW DEFINE A FUNCTION TO OPERATE ON EVERY INSTANCE OF A COLUMN

### DEFINE FIRST LETTER FUNCTION
## TAKE IN A STATE STRING
## RETURNS THE FIRST LETTER OF THAT STATE STRING

def grab_first_letter(state):
  return state[0]

# %%
grab_first_letter('NY')
# Out:
# 'N'

# %%
#NOW APPLY THE FUNCTION TO COLUMNS IN OUR STUFF
df_one['col2'].apply(grab_first_letter)
# Out:
# 0    N
# 1    C
# 2    W
# 3    W
# 4    A
# 5    N
# Name: col2, dtype: object

# %%
df_one['first_letter'] = df_one['col2'].apply(grab_first_letter)
df_one
# Out:
#   k1  col1 col2   NEW first_letter
# 0  A   100   NY  1000            N
# 1  A   200   CA  2000            C
# 2  B   300   WA  3000            W
# 3  B   300   WA  3000            W
# 4  C   400   AK  4000            A
# 5  C   500   NV  5000            N

# %%
##NOW MAP CURRENT NAMES TO VALUES IN YOU DATAFRAMES
my_map = {'A':1, 'B':2, 'C':3}

df_one['numbers'] = df_one['k1'].map(my_map)

df_one
# Out:
#   k1  col1 col2   NEW first_letter  numbers
# 0  A   100   NY  1000            N        1
# 1  A   200   CA  2000            C        1
# 2  B   300   WA  3000            W        2
# 3  B   300   WA  3000            W        2
# 4  C   400   AK  4000            A        3
# 5  C   500   NV  5000            N        3

# %%
df_one['col1'].max()
# Out:
# 500

# %%
df_one['col1'] #idxmin/idxmax for min and max values respectivly
# Out:
# 0    100
# 1    200
# 2    300
# 3    300
# 4    400
# 5    500
# Name: col1, dtype: int64

# %%
import pandas as pd
df_one = pd.DataFrame({'k1':['A','A','B','B','C','C'],
                      'col1':[100,200,300,300,400,500],
                      'col2':['NY','CA','WA','WA','AK','NV']})
df_one
# Out:
#   k1  col1 col2
# 0  A   100   NY
# 1  A   200   CA
# 2  B   300   WA
# 3  B   300   WA
# 4  C   400   AK
# 5  C   500   NV

# %%
df_one['col2'].unique()
# Out:
# array(['NY', 'CA', 'WA', 'AK', 'NV'], dtype=object)

# %%
df_one['col2'].nunique()
df_one['k1'].nunique()
# Out:
# 3

# %%
df_one['k1'].value_counts()
# Out:
# k1
# A    2
# B    2
# C    2
# Name: count, dtype: int64

# %%
df_one['k1'].drop_duplicates()
# Out:
# 0    A
# 2    B
# 4    C
# Name: k1, dtype: object

# %%
df_one['NEW'] = df_one['col1'] * 10

# %%
df_one
# Out:
#   k1  col1 col2   NEW
# 0  A   100   NY  1000
# 1  A   200   CA  2000
# 2  B   300   WA  3000
# 3  B   300   WA  3000
# 4  C   400   AK  4000
# 5  C   500   NV  5000

# %%
#NOW DEFINE A FUNCTION TO OPERATE ON EVERY INSTANCE OF A COLUMN

### DEFINE FIRST LETTER FUNCTION
## TAKE IN A STATE STRING
## RETURNS THE FIRST LETTER OF THAT STATE STRING

def grab_first_letter(state):
  return state[0]

# %%
grab_first_letter('NY')
# Out:
# 'N'

# %%
#NOW APPLY THE FUNCTION TO COLUMNS IN OUR STUFF
df_one['col2'].apply(grab_first_letter)
# Out:
# 0    N
# 1    C
# 2    W
# 3    W
# 4    A
# 5    N
# Name: col2, dtype: object

# %%
df_one['first_letter'] = df_one['col2'].apply(grab_first_letter)
df_one
# Out:
#   k1  col1 col2   NEW first_letter
# 0  A   100   NY  1000            N
# 1  A   200   CA  2000            C
# 2  B   300   WA  3000            W
# 3  B   300   WA  3000            W
# 4  C   400   AK  4000            A
# 5  C   500   NV  5000            N

# %%
##NOW MAP CURRENT NAMES TO VALUES IN YOU DATAFRAMES
my_map = {'A':1, 'B':2, 'C':3}

df_one['numbers'] = df_one['k1'].map(my_map)

df_one
# Out:
#   k1  col1 col2   NEW first_letter  numbers
# 0  A   100   NY  1000            N        1
# 1  A   200   CA  2000            C        1
# 2  B   300   WA  3000            W        2
# 3  B   300   WA  3000            W        2
# 4  C   400   AK  4000            A        3
# 5  C   500   NV  5000            N        3

# %%
df_one['col1'].max()
# Out:
# 500

# %%
df_one['col1'] #idxmin/idxmax for min and max values respectivly
# Out:
# 0    100
# 1    200
# 2    300
# 3    300
# 4    400
# 5    500
# Name: col1, dtype: int64

# %%
df_one.columns = ['C0', 'C1', 'C2', 'C3', 'C4', 'C5'] ## CHANGE COLUMN NAMES

# %%
df_one
# Out:
#   C0   C1  C2    C3 C4  C5
# 0  A  100  NY  1000  N   1
# 1  A  200  CA  2000  C   1
# 2  B  300  WA  3000  W   2
# 3  B  300  WA  3000  W   2
# 4  C  400  AK  4000  A   3
# 5  C  500  NV  5000  N   3

# %%
## SORT
df_one.sort_values('C5' )
# Out:
#   C0   C1  C2    C3 C4  C5
# 0  A  100  NY  1000  N   1
# 1  A  200  CA  2000  C   1
# 2  B  300  WA  3000  W   2
# 3  B  300  WA  3000  W   2
# 4  C  400  AK  4000  A   3
# 5  C  500  NV  5000  N   3

# %%
features = pd.DataFrame({'A':[100,200,300,400,500],
                        'B':[12,13,14,15,16]})
predictions = pd.DataFrame({'pred':[0,1,1,0,1]})

# %%
features
# Out:
#      A   B
# 0  100  12
# 1  200  13
# 2  300  14
# 3  400  15
# 4  500  16

# %%
features[features['A']>200] #A & B where [A] is greater than 200
# Out:
#      A   B
# 2  300  14
# 3  400  15
# 4  500  16

# %%
features
# Out:
#      A   B
# 0  100  12
# 1  200  13
# 2  300  14
# 3  400  15
# 4  500  16

# %%
pd.concat([features, predictions], axis = 1)#joins them along the columns otherwise they end up one under the other and then you have the NaN values seen before

# %%
# ONE HOT ENCODING
df_one

# %%
df_one['C1']

# %%
pd.get_dummies(df_one['C1'])

# %%
##########  DATA INPUT and OUTPUT
###READING FROM CSV
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Universit')

# %%
pwd

# %%
ls "/content/drive/MyDrive/Colab Notebooks/"
